# %% [markdown]
# #Read from CSV file

# %%
df=(
    spark.read.option("header","true")
    .option("inferSchema","true")
    .csv("/Volumes/workspace/bronze/sourcedata/source crm/cust_info.csv")
)
display(df)

# %% [markdown]
# #Write to bronze layer

# %%
df.write.mode("overwrite").saveAsTable("bronze.crm_cust_info")

# %%
df = (
    spark.read.format("csv")
    .option("header", "true")
    .option("inferSchema", "true")
    .load("/Volumes/workspace/bronze/sourcedata/source crm/prd_info.csv")
)

df.write.mode("overwrite").saveAsTable("bronze.crm_prd_info")

# %%
df = (
    spark.read.format("csv")
    .option("header", "true")
    .option("inferSchema", "true")
    .load("/Volumes/workspace/bronze/sourcedata/source crm/sales_details.csv")
)

df.write.mode("overwrite").saveAsTable("bronze.crm_sales_details")

# %%
df = (
    spark.read.format("csv")
    .option("header", "true")
    .option("inferSchema", "true")
    .load("/Volumes/workspace/bronze/sourcedata/Source ERP/CUST_AZ12.csv")
)

df.write.mode("overwrite").saveAsTable("bronze.erp_CUST_AZ12")

# %%
df = (
    spark.read.format("csv")
    .option("header", "true")
    .option("inferSchema", "true")
    .load("/Volumes/workspace/bronze/sourcedata/Source ERP/LOC_A101.csv")
)

df.write.mode("overwrite").saveAsTable("bronze.erp_LOC_A101")

# %%
df = (
    spark.read.format("csv")
    .option("header", "true")
    .option("inferSchema", "true")
    .load("/Volumes/workspace/bronze/sourcedata/Source ERP/PX_CAT_G1V2.csv")
)

df.write.mode("overwrite").saveAsTable("bronze.erp_PX_CAT_G1V2")

# %% [markdown]
# Completed
